# %%
import pandas as pd
import numpy as np

# %%
salesData = pd.read_csv('dunnhumby_breakfast.csv')
salesData['WEEK_END_DATE'] = pd.to_datetime(salesData['WEEK_END_DATE'], format="%d-%b-%y")
salesData['UPC'] = salesData['UPC'].astype(pd.Int64Dtype())

# %%
salesCereals = salesData.loc[(salesData['Sub-Category']=='ALL FAMILY CEREAL') & (salesData['STORE_NUM']==367) \
                            & (salesData['WEEK_END_DATE']>='2009-01-01')]
#print(salesCereals)

salesCereals['SUMPRICE'] = salesCereals['PRICE'].groupby(salesCereals['WEEK_END_DATE']).transform('sum')
salesCereals['COUNTPRICE'] = salesCereals['PRICE'].groupby(salesCereals['WEEK_END_DATE']).transform('count')
salesCereals['AVGPRICE'] = salesCereals['SUMPRICE']/salesCereals['COUNTPRICE']
salesCereals['RELPRICE'] = salesCereals['PRICE']/salesCereals['AVGPRICE']
print(salesCereals)
salesCereals.to_csv('./salesCereals.csv')
# Out:
# D:\Anaconda3\envs\pyomov2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\Anaconda3\envs\pyomov2\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Anaconda3\envs\pyomov2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# D:\Anaconda3\envs\pyomov2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        WEEK_END_DATE  STORE_NUM         UPC  UNITS  VISITS   HHS   SPEND  \
# 6         2009-01-14      367.0  1111085319   14.0    13.0  13.0   26.32
# 8         2009-01-14      367.0  1111085350   35.0    27.0  25.0   69.30
# 12        2009-01-14      367.0  1600027527   12.0    10.0  10.0   38.28
# 13        2009-01-14      367.0  1600027528   31.0    26.0  19.0  142.29
# 14        2009-01-14      367.0  1600027564   56.0    48.0  42.0  152.32
# 16        2009-01-14      367.0  3000006340   19.0    17.0  17.0   38.76
# 21        2009-01-14      367.0  3800031829   14.0    11.0   3.0   43.96
# 3163      2009-01-21      367.0  1111085319   12.0    12.0  12.0   22.68
# 3165      2009-01-21      367.0  1111085350   33.0    25.0  25.0   66.00
# 3169      2009-01-21      367.0  1600027527    7.0     7.0   7.0   22.33
# 3170      2009-01-21      367.0  1600027528   24.0    19.0  11.0  110.16
# 3171      2009-01-21      367.0  1600027564   36.0    23.0  23.0   96.48
# 3173      2009-01-21      367.0  3000006340    9.0     8.0   7.0   23.22
# 3177      2009-01-21      367.0  3800031829   17.0    13.0   6.0   53.38
# 6293      2009-01-28      367.0  1111085319   18.0    17.0  16.0   33.66
# 6295      2009-01-28      367.0  1111085350   30.0    21.0  20.0   60.30
# 6299      2009-01-28      367.0  1600027527    9.0     9.0   9.0   28.71
# 6300      2009-01-28      367.0  1600027528   27.0    21.0   7.0  123.93
# 6301      2009-01-28      367.0  1600027564   20.0    20.0  15.0   63.80
# 6303      2009-01-28      367.0  3000006340    3.0     3.0   2.0    8.22
# 6309      2009-01-28      367.0  3800031829   23.0    19.0   8.0   72.22
# 9426      2009-02-04      367.0  1111085319   13.0    13.0  13.0   24.44
# 9428      2009-02-04      367.0  1111085350   38.0    31.0  30.0   75.62
# 9432      2009-02-04      367.0  1600027527   18.0    17.0  16.0   57.42
# 9433      2009-02-04      367.0  1600027528   28.0    24.0  13.0  128.52
# 9434      2009-02-04      367.0  1600027564   16.0    14.0  10.0   51.04
# 9436      2009-02-04      367.0  3000006340    5.0     5.0   2.0   13.70
# 9440      2009-02-04      367.0  3800031829   25.0    23.0  10.0   78.50
# 12549     2009-02-11      367.0  1111085319   16.0    16.0  16.0   29.92
# 12551     2009-02-11      367.0  1111085350   38.0    27.0  26.0   74.86
# ...              ...        ...         ...    ...     ...   ...     ...
# 508651    2011-12-07      367.0  1111085319   12.0    12.0  12.0   21.84
# 508653    2011-12-07      367.0  1111085350   27.0    22.0  22.0   52.65
# 508657    2011-12-07      367.0  1600027527    9.0     9.0   8.0   28.08
# 508658    2011-12-07      367.0  1600027528   38.0    35.0  26.0  182.02
# 508659    2011-12-07      367.0  1600027564   17.0    16.0  15.0   47.77
# 508663    2011-12-07      367.0  3800031829   10.0     9.0   9.0   38.90
# 511901    2011-12-14      367.0  1111085319   14.0    14.0  14.0   22.82
# 511903    2011-12-14      367.0  1111085350   18.0    15.0  15.0   43.74
# 511907    2011-12-14      367.0  1600027527   14.0    14.0  14.0   43.68
# 511908    2011-12-14      367.0  1600027528   31.0    29.0  20.0  148.49
# 511909    2011-12-14      367.0  1600027564   35.0    31.0  28.0  111.65
# 511915    2011-12-14      367.0  3800031829   13.0    14.0  11.0   50.57
# 515179    2011-12-21      367.0  1111085319    8.0     8.0   8.0   13.36
# 515181    2011-12-21      367.0  1111085350   20.0    18.0  18.0   49.00
# 515185    2011-12-21      367.0  1600027527   57.0    48.0  45.0  113.43
# 515186    2011-12-21      367.0  1600027528   22.0    21.0  18.0  105.38
# 515187    2011-12-21      367.0  1600027564   19.0    18.0  16.0   54.15
# 515192    2011-12-21      367.0  3800031829   18.0    17.0  16.0   70.02
# 518443    2011-12-28      367.0  1111085319    3.0     2.0   2.0    4.95
# 518445    2011-12-28      367.0  1111085350    1.0     1.0   1.0    2.49
# 518449    2011-12-28      367.0  1600027527   39.0    33.0  33.0   78.78
# 518450    2011-12-28      367.0  1600027528   16.0    12.0  11.0   76.64
# 518451    2011-12-28      367.0  1600027564   21.0    20.0  17.0   66.99
# 518454    2011-12-28      367.0  3800031829   29.0    24.0  21.0  112.81
# 521628    2012-01-04      367.0  1111085319    4.0     2.0   2.0    6.64
# 521630    2012-01-04      367.0  1111085350    1.0     1.0   1.0    2.49
# 521634    2012-01-04      367.0  1600027527   31.0    29.0  29.0   59.83
# 521635    2012-01-04      367.0  1600027528   27.0    26.0  21.0  129.33
# 521636    2012-01-04      367.0  1600027564   35.0    29.0  25.0  111.65
# 521639    2012-01-04      367.0  3800031829   27.0    19.0  16.0  105.03
#
#         PRICE  BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY  \
# 6        1.88        1.88      0.0      0.0       0.0
# 8        1.98        1.98      0.0      0.0       0.0
# 12       3.19        3.19      0.0      0.0       0.0
# 13       4.59        4.59      0.0      0.0       0.0
# 14       2.72        3.07      1.0      0.0       0.0
# 16       2.04        2.74      0.0      0.0       1.0
# 21       3.14        3.14      0.0      0.0       0.0
# 3163     1.89        1.89      0.0      0.0       0.0
# 3165     2.00        2.00      0.0      0.0       0.0
# 3169     3.19        3.19      0.0      0.0       0.0
# 3170     4.59        4.59      0.0      0.0       0.0
# 3171     2.68        3.07      0.0      0.0       1.0
# 3173     2.58        2.58      0.0      0.0       0.0
# 3177     3.14        3.14      0.0      0.0       0.0
# 6293     1.87        1.87      0.0      0.0       0.0
# 6295     2.01        2.01      0.0      0.0       0.0
# 6299     3.19        3.19      0.0      0.0       0.0
# 6300     4.59        4.59      0.0      0.0       0.0
# 6301     3.19        3.19      0.0      0.0       0.0
# 6303     2.74        2.74      0.0      0.0       0.0
# 6309     3.14        3.14      0.0      0.0       0.0
# 9426     1.88        1.88      0.0      0.0       0.0
# 9428     1.99        1.99      0.0      0.0       0.0
# 9432     3.19        3.19      0.0      0.0       0.0
# 9433     4.59        4.59      0.0      0.0       0.0
# 9434     3.19        3.19      0.0      0.0       0.0
# 9436     2.74        2.74      0.0      0.0       0.0
# 9440     3.14        3.14      0.0      0.0       0.0
# 12549    1.87        1.87      0.0      0.0       0.0
# 12551    1.97        1.97      0.0      0.0       0.0
# ...       ...         ...      ...      ...       ...
# 508651   1.82        1.82      0.0      0.0       0.0
# 508653   1.95        2.47      0.0      0.0       1.0
# 508657   3.12        3.12      0.0      0.0       0.0
# 508658   4.79        4.79      0.0      0.0       0.0
# 508659   2.81        2.81      0.0      0.0       0.0
# 508663   3.89        3.89      0.0      0.0       0.0
# 511901   1.63        1.82      0.0      0.0       1.0
# 511903   2.43        2.43      0.0      0.0       0.0
# 511907   3.12        3.12      0.0      0.0       0.0
# 511908   4.79        4.79      0.0      0.0       0.0
# 511909   3.19        3.19      0.0      0.0       0.0
# 511915   3.89        3.89      0.0      0.0       0.0
# 515179   1.67        1.67      0.0      0.0       0.0
# 515181   2.45        2.45      0.0      0.0       0.0
# 515185   1.99        3.12      1.0      1.0       0.0
# 515186   4.79        4.79      0.0      0.0       0.0
# 515187   2.85        3.19      0.0      0.0       1.0
# 515192   3.89        3.89      0.0      0.0       0.0
# 518443   1.65        1.65      0.0      0.0       0.0
# 518445   2.49        2.49      0.0      0.0       0.0
# 518449   2.02        3.12      1.0      0.0       0.0
# 518450   4.79        4.79      0.0      0.0       0.0
# 518451   3.19        3.19      0.0      0.0       0.0
# 518454   3.89        3.89      0.0      0.0       0.0
# 521628   1.66        1.66      0.0      0.0       0.0
# 521630   2.49        2.49      0.0      0.0       0.0
# 521634   1.93        3.12      1.0      0.0       0.0
# 521635   4.79        4.79      0.0      0.0       0.0
# 521636   3.19        3.19      0.0      0.0       0.0
# 521639   3.89        3.89      0.0      0.0       0.0
#
#                              Desc     Category       Sub-Category  SUMPRICE  \
# 6        PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     19.54
# 8         PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     19.54
# 12          GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     19.54
# 13                    GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     19.54
# 14                    GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     19.54
# 16             QKER LIFE ORIGINAL  COLD CEREAL  ALL FAMILY CEREAL     19.54
# 21      KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     19.54
# 3163     PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     20.07
# 3165      PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     20.07
# 3169        GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.07
# 3170                  GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.07
# 3171                  GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.07
# 3173           QKER LIFE ORIGINAL  COLD CEREAL  ALL FAMILY CEREAL     20.07
# 3177    KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     20.07
# 6293     PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     20.73
# 6295      PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     20.73
# 6299        GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.73
# 6300                  GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.73
# 6301                  GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.73
# 6303           QKER LIFE ORIGINAL  COLD CEREAL  ALL FAMILY CEREAL     20.73
# 6309    KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     20.73
# 9426     PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     20.72
# 9428      PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     20.72
# 9432        GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.72
# 9433                  GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.72
# 9434                  GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     20.72
# 9436           QKER LIFE ORIGINAL  COLD CEREAL  ALL FAMILY CEREAL     20.72
# 9440    KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     20.72
# 12549    PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     15.96
# 12551     PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     15.96
# ...                           ...          ...                ...       ...
# 508651   PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     18.38
# 508653    PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     18.38
# 508657      GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     18.38
# 508658                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     18.38
# 508659                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     18.38
# 508663  KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     18.38
# 511901   PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     19.05
# 511903    PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     19.05
# 511907      GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     19.05
# 511908                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     19.05
# 511909                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     19.05
# 511915  KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     19.05
# 515179   PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     17.64
# 515181    PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     17.64
# 515185      GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     17.64
# 515186                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     17.64
# 515187                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     17.64
# 515192  KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     17.64
# 518443   PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     18.03
# 518445    PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     18.03
# 518449      GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     18.03
# 518450                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     18.03
# 518451                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     18.03
# 518454  KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     18.03
# 521628   PL HONEY NUT TOASTD OATS  COLD CEREAL  ALL FAMILY CEREAL     17.95
# 521630    PL BT SZ FRSTD SHRD WHT  COLD CEREAL  ALL FAMILY CEREAL     17.95
# 521634      GM HONEY NUT CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     17.95
# 521635                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     17.95
# 521636                GM CHEERIOS  COLD CEREAL  ALL FAMILY CEREAL     17.95
# 521639  KELL BITE SIZE MINI WHEAT  COLD CEREAL  ALL FAMILY CEREAL     17.95
#
#         COUNTPRICE  AVGPRICE  RELPRICE
# 6                7  2.791429  0.673490
# 8                7  2.791429  0.709314
# 12               7  2.791429  1.142784
# 13               7  2.791429  1.644319
# 14               7  2.791429  0.974411
# 16               7  2.791429  0.730809
# 21               7  2.791429  1.124872
# 3163             7  2.867143  0.659193
# 3165             7  2.867143  0.697559
# 3169             7  2.867143  1.112606
# 3170             7  2.867143  1.600897
# 3171             7  2.867143  0.934728
# 3173             7  2.867143  0.899851
# 3177             7  2.867143  1.095167
# 6293             7  2.961429  0.631452
# 6295             7  2.961429  0.678726
# 6299             7  2.961429  1.077183
# 6300             7  2.961429  1.549928
# 6301             7  2.961429  1.077183
# 6303             7  2.961429  0.925229
# 6309             7  2.961429  1.060299
# 9426             7  2.960000  0.635135
# 9428             7  2.960000  0.672297
# 9432             7  2.960000  1.077703
# 9433             7  2.960000  1.550676
# 9434             7  2.960000  1.077703
# 9436             7  2.960000  0.925676
# 9440             7  2.960000  1.060811
# 12549            7  2.280000  0.820175
# 12551            7  2.280000  0.864035
# ...            ...       ...       ...
# 508651           6  3.063333  0.594124
# 508653           6  3.063333  0.636561
# 508657           6  3.063333  1.018498
# 508658           6  3.063333  1.563656
# 508659           6  3.063333  0.917301
# 508663           6  3.063333  1.269859
# 511901           6  3.175000  0.513386
# 511903           6  3.175000  0.765354
# 511907           6  3.175000  0.982677
# 511908           6  3.175000  1.508661
# 511909           6  3.175000  1.004724
# 511915           6  3.175000  1.225197
# 515179           6  2.940000  0.568027
# 515181           6  2.940000  0.833333
# 515185           6  2.940000  0.676871
# 515186           6  2.940000  1.629252
# 515187           6  2.940000  0.969388
# 515192           6  2.940000  1.323129
# 518443           6  3.005000  0.549085
# 518445           6  3.005000  0.828619
# 518449           6  3.005000  0.672213
# 518450           6  3.005000  1.594010
# 518451           6  3.005000  1.061564
# 518454           6  3.005000  1.294509
# 521628           6  2.991667  0.554875
# 521630           6  2.991667  0.832312
# 521634           6  2.991667  0.645125
# 521635           6  2.991667  1.601114
# 521636           6  2.991667  1.066295
# 521639           6  2.991667  1.300279
#
# [1067 rows x 19 columns]

# %%
#print(sales_data)
print(salesCereals.groupby('UPC').count())
productList = salesCereals['UPC'].unique()
print(productList)
# Out:
#             WEEK_END_DATE  STORE_NUM  UNITS  VISITS  HHS  SPEND  PRICE  \
# UPC
# 1111085319            156        156    156     156  156    156    156
# 1111085350            156        156    156     156  156    156    156
# 1600027527            156        156    156     156  156    156    156
# 1600027528            156        156    156     156  156    156    156
# 1600027564            155        155    155     155  155    155    155
# 3000006340            133        133    133     133  133    133    133
# 3800031829            155        155    155     155  155    155    155
#
#             BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY  Desc  Category  \
# UPC
# 1111085319         156      156      156       156   156       156
# 1111085350         156      156      156       156   156       156
# 1600027527         156      156      156       156   156       156
# 1600027528         156      156      156       156   156       156
# 1600027564         155      155      155       155   155       155
# 3000006340         133      133      133       133   133       133
# 3800031829         155      155      155       155   155       155
#
#             Sub-Category  SUMPRICE  COUNTPRICE  AVGPRICE  RELPRICE
# UPC
# 1111085319           156       156         156       156       156
# 1111085350           156       156         156       156       156
# 1600027527           156       156         156       156       156
# 1600027528           156       156         156       156       156
# 1600027564           155       155         155       155       155
# 3000006340           133       133         133       133       133
# 3800031829           155       155         155       155       155
# <IntegerArray>
# [1111085319, 1111085350, 1600027527, 1600027528, 1600027564, 3000006340,
#  3800031829]
# Length: 7, dtype: Int64

# %%
feature_list = ['PRICE', 'FEATURE', 'DISPLAY','TPR_ONLY','RELPRICE']
X_train, X_test = {}, {}
y_train, y_test, y_pred = {}, {}, {}


for k in productList:
    productDataSize = len(salesCereals.loc[salesCereals['UPC']==k][feature_list].values)
    
    train_size = int(productDataSize * 0.75)
    print("N.Points[" + str(k) + "]:" + str(productDataSize)+", N.TrainPoints[" + str(k) + "]:" + str(train_size))

    X_train[k] = salesCereals.loc[salesCereals['UPC']==k][feature_list].values[0:train_size]
    X_test[k] = salesCereals.loc[salesCereals['UPC']==k][feature_list].values[train_size:productDataSize]
    
    y_train[k] = salesCereals.loc[salesCereals['UPC']==k]['UNITS'].values[0:train_size]
    y_test[k] = salesCereals.loc[salesCereals['UPC']==k]['UNITS'].values[train_size:productDataSize]
# Out:
# N.Points[1111085319]:156, N.TrainPoints[1111085319]:117
# N.Points[1111085350]:156, N.TrainPoints[1111085350]:117
# N.Points[1600027527]:156, N.TrainPoints[1600027527]:117
# N.Points[1600027528]:156, N.TrainPoints[1600027528]:117
# N.Points[1600027564]:155, N.TrainPoints[1600027564]:116
# N.Points[3000006340]:133, N.TrainPoints[3000006340]:99
# N.Points[3800031829]:155, N.TrainPoints[3800031829]:116

# %%
#Tree model
from sklearn import tree
from sklearn.metrics import mean_absolute_error
import pickle

regr = {}

for k in productList:
      
    regr[k] = tree.DecisionTreeRegressor(max_depth = 5).fit(X_train[k],y_train[k])
    y_pred[k] = regr[k].predict(X_test[k])
    
    print("UPC:"+str(k))
    print("\tMAE:" + "{0:.2f}".format(mean_absolute_error(y_test[k], y_pred[k])))
    print("\tMAPE:" + "{0:.2f}".format(np.mean(np.abs((y_test[k] - y_pred[k]) / y_test[k]) * 100))+'%')
    
    print("\tFeature importance")
    for i in range(len(feature_list)):
        print("\t\t"+str(feature_list[i])+':'+"{0:.2f}".format(regr[k].feature_importances_[i]*100)+'%')
        
    # save the model to disk
    filename = './'+str(k)+'_tree_model.sav'
    pickle.dump(regr[k], open(filename, 'wb'))
# Out:
# UPC:1111085319
# 	MAE:6.56
# 	MAPE:70.73%
# 	Feature importance
# 		PRICE:20.40%
# 		FEATURE:0.32%
# 		DISPLAY:0.00%
# 		TPR_ONLY:10.83%
# 		RELPRICE:68.45%
# UPC:1111085350
# 	MAE:7.12
# 	MAPE:105.02%
# 	Feature importance
# 		PRICE:35.65%
# 		FEATURE:0.55%
# 		DISPLAY:35.71%
# 		TPR_ONLY:0.00%
# 		RELPRICE:28.08%
# UPC:1600027527
# 	MAE:16.29
# 	MAPE:125.57%
# 	Feature importance
# 		PRICE:16.42%
# 		FEATURE:0.00%
# 		DISPLAY:73.16%
# 		TPR_ONLY:0.00%
# 		RELPRICE:10.42%
# UPC:1600027528
# 	MAE:7.51
# 	MAPE:23.41%
# 	Feature importance
# 		PRICE:76.31%
# 		FEATURE:0.00%
# 		DISPLAY:2.80%
# 		TPR_ONLY:0.00%
# 		RELPRICE:20.88%
# UPC:1600027564
# 	MAE:6.82
# 	MAPE:19.86%
# 	Feature importance
# 		PRICE:12.84%
# 		FEATURE:49.84%
# 		DISPLAY:13.91%
# 		TPR_ONLY:0.00%
# 		RELPRICE:23.40%
# UPC:3000006340
# 	MAE:5.44
# 	MAPE:186.49%
# 	Feature importance
# 		PRICE:20.57%
# 		FEATURE:0.00%
# 		DISPLAY:0.00%
# 		TPR_ONLY:0.00%
# 		RELPRICE:79.43%
# UPC:3800031829
# 	MAE:7.66
# 	MAPE:31.50%
# 	Feature importance
# 		PRICE:21.03%
# 		FEATURE:0.21%
# 		DISPLAY:55.29%
# 		TPR_ONLY:0.00%
# 		RELPRICE:23.47%

# %%
from dtreeviz.trees import *
from IPython.display import Image

for k in productList[:3]:
    viz = dtreeviz(regr[k],
                   X_train[k],
                   y_train[k],
                   target_name='Sales',
                   feature_names=np.array(feature_list))

    viz.save("./"+str(k)+".svg")

# %%
k = productList[0]

viz = dtreeviz(regr[k],
               X_train[k],
               y_train[k],
               target_name='Sales',
               feature_names=np.array(feature_list),
              X = X_train[k][0])

viz.save("./"+str(k)+"_data_sample.svg")

# %%
#Linear model
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
import pickle

regr = {}

for k in productList:
      
    regr[k] = linear_model.LinearRegression().fit(X_train[k],y_train[k])
    
    y_pred[k] = regr[k].predict(X_test[k])
    print("UPC:"+str(k))
    print("\tMAE:" + "{0:.2f}".format(mean_absolute_error(y_test[k], y_pred[k])))
    print("\tMAPE:" + "{0:.2f}".format(np.mean(np.abs((y_test[k] - y_pred[k]) / y_test[k]) * 100))+'%')
    
    print("\tRegression parameters")
    
    print("\t\t"+str('çonstant')+':'+"{0:.2f}".format(regr[k].intercept_))
    for i in range(len(feature_list)):
        print("\t\t"+str(feature_list[i])+':'+"{0:.2f}".format(regr[k].coef_[i]))
        
    filename = './'+str(k)+'_linear_model.sav'
    pickle.dump(regr[k], open(filename, 'wb'))
# Out:
# UPC:1111085319
# 	MAE:7.04
# 	MAPE:66.84%
# 	Regression parameters
# 		çonstant:52.22
# 		PRICE:-15.55
# 		FEATURE:2.25
# 		DISPLAY:0.00
# 		TPR_ONLY:4.04
# 		RELPRICE:-14.39
# UPC:1111085350
# 	MAE:6.51
# 	MAPE:97.37%
# 	Regression parameters
# 		çonstant:48.23
# 		PRICE:-22.73
# 		FEATURE:7.29
# 		DISPLAY:17.87
# 		TPR_ONLY:0.56
# 		RELPRICE:25.34
# UPC:1600027527
# 	MAE:16.45
# 	MAPE:69.92%
# 	Regression parameters
# 		çonstant:45.08
# 		PRICE:-23.58
# 		FEATURE:27.43
# 		DISPLAY:72.15
# 		TPR_ONLY:-4.61
# 		RELPRICE:40.90
# UPC:1600027528
# 	MAE:10.56
# 	MAPE:32.44%
# 	Regression parameters
# 		çonstant:222.67
# 		PRICE:-34.99
# 		FEATURE:-7.93
# 		DISPLAY:-15.74
# 		TPR_ONLY:0.00
# 		RELPRICE:-23.30
# UPC:1600027564
# 	MAE:5.74
# 	MAPE:18.23%
# 	Regression parameters
# 		çonstant:21.60
# 		PRICE:1.00
# 		FEATURE:14.77
# 		DISPLAY:16.13
# 		TPR_ONLY:0.82
# 		RELPRICE:-3.06
# UPC:3000006340
# 	MAE:2.69
# 	MAPE:96.27%
# 	Regression parameters
# 		çonstant:11.73
# 		PRICE:-4.83
# 		FEATURE:10.09
# 		DISPLAY:3.14
# 		TPR_ONLY:3.05
# 		RELPRICE:7.56
# UPC:3800031829
# 	MAE:6.92
# 	MAPE:29.86%
# 	Regression parameters
# 		çonstant:60.40
# 		PRICE:-10.47
# 		FEATURE:2.79
# 		DISPLAY:23.07
# 		TPR_ONLY:8.06
# 		RELPRICE:-4.07

# %%
import matplotlib.pyplot as plt

#See https://matplotlib.org/devdocs/gallery/subplots_axes_and_figures/subplots_demo.html

def plot(data_x, data_y, X_test, y_pred, feature_list):
    # Plot the results

    n_row_plot = int((len(feature_list)+1)/2) # 2 plots per row
    n_col_plot = 2
    fig, ax = plt.subplots(n_row_plot, n_col_plot, figsize=(12, 12))
    
    i = 0 # column index of the plot
    j = 0 # row index of the plot
        
    for count in range(len(feature_list)):
        #print(data_x[:,i])
        ax[j, i].scatter(data_x[:,min(count,len(feature_list))], data_y, s=20, edgecolor="black",
                    c="darkorange", label="data")
        ax[j, i].scatter(X_test[:,min(count,len(feature_list))], y_pred, s=30, marker="X", 
                    c="royalblue", label="prediction")
        ax[j, i].set(title=feature_list[count])
        
        ax[j, i].set(ylabel='UNITS')
            
        i = min(i+1,len(feature_list)) % n_col_plot
        if i == 0: j += 1

    plt.show()

# %%
# Plot prediction results for a product (UPC)
k = productList[5]
data_y = salesCereals.loc[salesCereals['UPC']==k]['UNITS'].values
data_x = salesCereals.loc[salesCereals['UPC']==k][feature_list].values

plot(data_x, data_y, X_test[k], y_pred[k], feature_list)
